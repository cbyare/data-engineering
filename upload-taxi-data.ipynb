# %%
# !pip install sqlalchemy
# Out:
# ...
# WARNING: You are using pip version 22.0.3; however, version 24.0 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.10/bin/python3.10 -m pip install --upgrade pip' command.

# %%
import sqlalchemy as db

# %%
import pandas as pd

# %%
engine=db.create_engine('postgresql://root:root@localhost:5432/ny_taxi')

# %%
engine.connect()

# %%
query = """
SELECT 1 as number;
"""
pd.read_sql(query,con=engine)
# Out:
#    number
# 0       1

# %%
query = """
SELECT * 
FROM pg_catalog.pg_tables
WHERE schemaname!='pg_catalog' AND schemaname!='information_schema';
"""
pd.read_sql(query,con=engine)
# Out:
#   schemaname         tablename tableowner tablespace  hasindexes  hasrules  \
# 0     public  yellow_trip_data       root       None       False     False
# 1     public  yellow_taxi_data       root       None        True     False
#
#    hastriggers  rowsecurity
# 0        False        False
# 1        False        False

# %%
df = pd.read_csv('yellow_tripdata_2023-01.csv',nrows=100)

# %%
df.head()
# Out:
#    Unnamed: 0  VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0           0         2  2023-01-01 00:32:10   2023-01-01 00:40:36
# 1           1         2  2023-01-01 00:55:08   2023-01-01 01:01:27
# 2           2         2  2023-01-01 00:25:04   2023-01-01 00:37:49
# 3           3         1  2023-01-01 00:03:48   2023-01-01 00:13:25
# 4           4         2  2023-01-01 00:10:29   2023-01-01 00:21:19
#
#    passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 0              1.0           0.97         1.0                  N
# 1              1.0           1.10         1.0                  N
# 2              1.0           2.51         1.0                  N
# 3              0.0           1.90         1.0                  N
# 4              1.0           1.43         1.0                  N
#
#    PULocationID  DOLocationID  payment_type  fare_amount  extra  mta_tax  \
# 0           161           141             2          9.3   1.00      0.5
# ...

# %%
df.to_sql(name='yellow_trip_data',con=engine,index=False)
# Out:
# 100

# %%
query = """
SELECT * 
FROM yellow_trip_data
limit 5;
"""
pd.read_sql(query,con=engine)
# Out:
#    Unnamed: 0  VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0           0         2  2023-01-01 00:32:10   2023-01-01 00:40:36
# 1           1         2  2023-01-01 00:55:08   2023-01-01 01:01:27
# 2           2         2  2023-01-01 00:25:04   2023-01-01 00:37:49
# 3           3         1  2023-01-01 00:03:48   2023-01-01 00:13:25
# 4           4         2  2023-01-01 00:10:29   2023-01-01 00:21:19
#
#    passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 0              1.0           0.97         1.0                  N
# 1              1.0           1.10         1.0                  N
# 2              1.0           2.51         1.0                  N
# 3              0.0           1.90         1.0                  N
# 4              1.0           1.43         1.0                  N
#
#    PULocationID  DOLocationID  payment_type  fare_amount  extra  mta_tax  \
# 0           161           141             2          9.3   1.00      0.5
# ...

# %% [markdown]
# ## real things

# %%
df = df_iter=pd.read_csv('yellow_tripdata_2023-01.csv',iterator=True, chunksize=100000)

# %%
df = next(df_iter)

# %%
len(df)
# Out:
# 100000

# %%
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]

# %%
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2023-01-01 00:32:10   2023-01-01 00:40:36              1.0
# 1         2  2023-01-01 00:55:08   2023-01-01 01:01:27              1.0
# 2         2  2023-01-01 00:25:04   2023-01-01 00:37:49              1.0
# 3         1  2023-01-01 00:03:48   2023-01-01 00:13:25              0.0
# 4         2  2023-01-01 00:10:29   2023-01-01 00:21:19              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           0.97         1.0                  N           161           141
# 1           1.10         1.0                  N            43           237
# 2           2.51         1.0                  N            48           238
# 3           1.90         1.0                  N           138             7
# 4           1.43         1.0                  N           107            79
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
df.tpep_pickup_datetime=pd.to_datetime(df.tpep_pickup_datetime)
df.tpep_dropoff_datetime=pd.to_datetime(df.tpep_dropoff_datetime)

# %%
print(pd.io.sql.get_schema(df,name='yellow_taxi_data',con=engine))
# Out:
# CREATE TABLE yellow_taxi_data (
# 	"VendorID" BIGINT,
# 	tpep_pickup_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	tpep_dropoff_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	passenger_count FLOAT(53),
# 	trip_distance FLOAT(53),
# 	"RatecodeID" FLOAT(53),
# 	store_and_fwd_flag TEXT,
# 	"PULocationID" BIGINT,
# 	"DOLocationID" BIGINT,
# 	payment_type BIGINT,
# 	fare_amount FLOAT(53),
# 	extra FLOAT(53),
# 	mta_tax FLOAT(53),
# 	tip_amount FLOAT(53),
# 	tolls_amount FLOAT(53),
# 	improvement_surcharge FLOAT(53),
# 	total_amount FLOAT(53),
# 	congestion_surcharge FLOAT(53),
# 	airport_fee FLOAT(53)
# )

# %%
df.head(n=0)
# Out:
# Empty DataFrame
# Columns: [VendorID, tpep_pickup_datetime, tpep_dropoff_datetime, passenger_count, trip_distance, RatecodeID, store_and_fwd_flag, PULocationID, DOLocationID, payment_type, fare_amount, extra, mta_tax, tip_amount, tolls_amount, improvement_surcharge, total_amount, congestion_surcharge, airport_fee]
# Index: []

# %%
df.head(n=0).to_sql(name='yellow_taxi_data',con=engine,if_exists='replace')
# Out:
# 0

# %%
# %time df.to_sql(name='yellow_taxi_data',con=engine,if_exists='append')
# Out:
# CPU times: user 2.15 s, sys: 95.8 ms, total: 2.24 s
# Wall time: 4.24 s
# 1000

# %%
query = """
SELECT *
FROM yellow_taxi_data 
LIMIT 10;
"""
pd.read_sql(query,con=engine)
# Out:
# Empty DataFrame
# Columns: [index, Unnamed: 0, VendorID, tpep_pickup_datetime, tpep_dropoff_datetime, passenger_count, trip_distance, RatecodeID, store_and_fwd_flag, PULocationID, DOLocationID, payment_type, fare_amount, extra, mta_tax, tip_amount, tolls_amount, improvement_surcharge, total_amount, congestion_surcharge, airport_fee]
# Index: []
#
# [0 rows x 21 columns]

# %%
query = """
SELECT COUNT(*)
FROM yellow_taxi_data;
"""
pd.read_sql(query,con=engine)
# Out:
#      count
# 0  2666766

# %%
from time import time

# %%
while True:
    t_start = time()
    df = next(df_iter)

    df.tpep_pickup_datetime=pd.to_datetime(df.tpep_pickup_datetime)
    df.tpep_dropoff_datetime=pd.to_datetime(df.tpep_dropoff_datetime)

    df.to_sql(name='yellow_taxi_data',con=engine,if_exists='append')

    t_end =time()
    
    print('inserted aonther chunks ...., took %.3f second' % (t_end - t_start))
# Out:
# inserted aonther chunks ...., took 5.044 second
# inserted aonther chunks ...., took 4.818 second
# inserted aonther chunks ...., took 4.681 second
# inserted aonther chunks ...., took 4.736 second
# inserted aonther chunks ...., took 4.777 second
# inserted aonther chunks ...., took 4.727 second
# inserted aonther chunks ...., took 4.799 second
# inserted aonther chunks ...., took 4.743 second
# inserted aonther chunks ...., took 5.003 second
# inserted aonther chunks ...., took 5.242 second
# inserted aonther chunks ...., took 4.903 second
# inserted aonther chunks ...., took 4.804 second
# inserted aonther chunks ...., took 5.069 second
# inserted aonther chunks ...., took 5.245 second
# inserted aonther chunks ...., took 4.948 second
# inserted aonther chunks ...., took 4.836 second
# inserted aonther chunks ...., took 4.979 second
# inserted aonther chunks ...., took 4.932 second
# inserted aonther chunks ...., took 4.946 second
# inserted aonther chunks ...., took 4.972 second
# ...
